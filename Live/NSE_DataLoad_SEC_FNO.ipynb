# %%
import pandas as pd
from zipfile import ZipFile
import numpy as np
from datetime import datetime, timedelta,date
from urllib.request import urlopen
from io import BytesIO
from pymongo import MongoClient

# %%
sec_base_url='https://archives.nseindia.com/products/content'
fno_base_url='https://archives.nseindia.com/content/historical/DERIVATIVES'

# %%
def date_range(start,end):
    daterange=np.arange(np.datetime64(start), np.datetime64(end)).astype(datetime)
    #print (daterange)
    return daterange

# %%
def download_data(currentdate):
    print (f"Called Download data for date {currentdate}")
    sec_date=currentdate.strftime('%d%m%Y')
    fno_day=currentdate.strftime("%d")
    fno_month=currentdate.strftime("%b").upper()
    fno_year=currentdate.strftime("%Y")
    fno_date=currentdate.strftime('%d%b%Y').upper()
    sec_url=f"{sec_base_url}/sec_bhavdata_full_{sec_date}.csv"
    fno_url=f"{fno_base_url}/{fno_year}/{fno_month}/fo{fno_date}bhav.csv.zip"
    fno_csv_file_name=f"fo{fno_date}bhav.csv"
    file_found= False
    try:
        # Download the fno file
        print (f"Download of FNO for {currentdate} Started from {fno_url}")
        resp = urlopen(fno_url,timeout=2)
        file_found=True
    except:
        file_found= False
    if file_found==True:
        zipfile = ZipFile(BytesIO(resp.read()))
        myfile=zipfile.extractall()
        listOfiles=zipfile.infolist()
        for elem in listOfiles:
            fno_csv_file_name=elem.filename
        df_fno=pd.read_csv(fno_csv_file_name,skipinitialspace = True)
        if not df_fno.empty:
            print (f"Download of FNO for {currentdate} Completed")
            df_fno= df_fno.rename(str.strip, axis = 'columns')
    else:
        print(f" FNO File is not present for {currentdate}")
        df_fno=pd.DataFrame()
        
        
    try: 
        # Download the sec file
        print (f"Download of SEC for {currentdate} Started from {sec_url}")
        resp = urlopen(sec_url,timeout=2)
        file_found=True
    except:
        file_found= False
    if file_found==True:        
        df_sec=pd.read_csv(sec_url,skipinitialspace = True)
        if not df_sec.empty:
            print (f"Download of SEC for {currentdate} Completed")
            df_sec= df_sec.rename(str.strip, axis = 'columns')
    else:
        print(f" Sec File is not present for {currentdate}")
        df_sec=pd.DataFrame()
        
    
    #print (df_sec)
    return df_sec,df_fno

# %%
def load_to_db(startdate,enddate):
    dbname='STAGINGDB'+startdate.split('-')[1]+startdate.split('-')[0]
    print(f'staging db is being created with name {dbname}')
    m_client=MongoClient()
    db=m_client[dbname]
    daterange=date_range(startdate,enddate)
    for currentdate in daterange:
        print(currentdate)
        df_sec,df_fno=download_data(currentdate)
        if not df_sec.empty:
            print(f" Security File loading for date {currentdate} started")
            data_sec=df_sec.to_dict(orient='records')
            db['SECMASTER'].insert_many(data_sec)
            print(f" Security File loading for date {currentdate} Ended")
        if not df_fno.empty:
            print(f" Security File loading for date {currentdate} started")
            data_fno=df_fno.to_dict(orient='records')
            db['FNOMASTER'].insert_many(data_fno)
            print(f" Security File loading for date {currentdate} Ended")
    m_client.close()

# %%
#startdate='2019-10-01'
# # ifwant to load data from 1st jan to 31 jan then give start date as 2021-01-01 and end as 2021-02-01(one day extra)
# startdate='2021-05-12'
# enddate='2021-11-19'

# %%
#load_to_db(startdate,enddate)

# %%
#This method read data from Mongo DB
def getdata(stock,db):
    stock=str(stock)
    mongo_client=MongoClient()
    db=mongo_client[db]
    data=db[stock].find()
    df=pd.DataFrame(list(data))
    df.drop("_id",axis=1,inplace=True)
    ###Covert to UTC to get the correct Values
    df['Datetime']=pd.to_datetime(df['Datetime']).dt.tz_localize('UTC').dt.tz_convert('Asia/Kolkata')
    #df['Datetime']=pd.to_datetime(df['Datetime'])
    df=df.set_index('Datetime')
    return df

# %%
enddate=str(date.today()+timedelta(days=1))
testdf=getdata('ACC','NSEEQ')
startdate=str(testdf.tail(1).index[0]+timedelta(days=1)).split(' ')[0]
startdate
# Out:
# '2021-12-01'

# %%
#

# %%
dbname='STAGINGDB'+startdate.split('-')[1]+startdate.split('-')[0]
dbname
# Out:
# 'STAGINGDB122021'

# %%
load_to_db(startdate,enddate)
# Out:
# staging db is being created with name STAGINGDB122021
# 2021-12-01
# Called Download data for date 2021-12-01
# Download of FNO for 2021-12-01 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo01DEC2021bhav.csv.zip
# Download of FNO for 2021-12-01 Completed
# Download of SEC for 2021-12-01 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_01122021.csv
# Download of SEC for 2021-12-01 Completed
#  Security File loading for date 2021-12-01 started
#  Security File loading for date 2021-12-01 Ended
#  Security File loading for date 2021-12-01 started
#  Security File loading for date 2021-12-01 Ended
# 2021-12-02
# Called Download data for date 2021-12-02
# Download of FNO for 2021-12-02 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo02DEC2021bhav.csv.zip
# Download of FNO for 2021-12-02 Completed
# Download of SEC for 2021-12-02 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_02122021.csv
# Download of SEC for 2021-12-02 Completed
#  Security File loading for date 2021-12-02 started
#  Security File loading for date 2021-12-02 Ended
#  Security File loading for date 2021-12-02 started
#  Security File loading for date 2021-12-02 Ended
# 2021-12-03
# Called Download data for date 2021-12-03
# Download of FNO for 2021-12-03 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo03DEC2021bhav.csv.zip
# Download of FNO for 2021-12-03 Completed
# Download of SEC for 2021-12-03 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_03122021.csv
# Download of SEC for 2021-12-03 Completed
#  Security File loading for date 2021-12-03 started
#  Security File loading for date 2021-12-03 Ended
#  Security File loading for date 2021-12-03 started
#  Security File loading for date 2021-12-03 Ended
# 2021-12-04
# Called Download data for date 2021-12-04
# Download of FNO for 2021-12-04 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo04DEC2021bhav.csv.zip
#  FNO File is not present for 2021-12-04
# Download of SEC for 2021-12-04 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_04122021.csv
#  Sec File is not present for 2021-12-04
# 2021-12-05
# Called Download data for date 2021-12-05
# Download of FNO for 2021-12-05 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo05DEC2021bhav.csv.zip
#  FNO File is not present for 2021-12-05
# Download of SEC for 2021-12-05 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_05122021.csv
# Download of SEC for 2021-12-05 Completed
#  Security File loading for date 2021-12-05 started
#  Security File loading for date 2021-12-05 Ended
# 2021-12-06
# Called Download data for date 2021-12-06
# Download of FNO for 2021-12-06 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo06DEC2021bhav.csv.zip
# Download of FNO for 2021-12-06 Completed
# Download of SEC for 2021-12-06 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_06122021.csv
# Download of SEC for 2021-12-06 Completed
#  Security File loading for date 2021-12-06 started
#  Security File loading for date 2021-12-06 Ended
#  Security File loading for date 2021-12-06 started
#  Security File loading for date 2021-12-06 Ended
# 2021-12-07
# Called Download data for date 2021-12-07
# Download of FNO for 2021-12-07 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo07DEC2021bhav.csv.zip
# Download of FNO for 2021-12-07 Completed
# Download of SEC for 2021-12-07 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full
Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo16DEC2021bhav.csv.zip
# Download of FNO for 2021-12-16 Completed
# Download of SEC for 2021-12-16 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_16122021.csv
# Download of SEC for 2021-12-16 Completed
#  Security File loading for date 2021-12-16 started
#  Security File loading for date 2021-12-16 Ended
#  Security File loading for date 2021-12-16 started
#  Security File loading for date 2021-12-16 Ended
# 2021-12-17
# Called Download data for date 2021-12-17
# Download of FNO for 2021-12-17 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo17DEC2021bhav.csv.zip
# Download of FNO for 2021-12-17 Completed
# Download of SEC for 2021-12-17 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_17122021.csv
# Download of SEC for 2021-12-17 Completed
#  Security File loading for date 2021-12-17 started
#  Security File loading for date 2021-12-17 Ended
#  Security File loading for date 2021-12-17 started
#  Security File loading for date 2021-12-17 Ended
# 2021-12-18
# Called Download data for date 2021-12-18
# Download of FNO for 2021-12-18 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo18DEC2021bhav.csv.zip
#  FNO File is not present for 2021-12-18
# Download of SEC for 2021-12-18 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_18122021.csv
#  Sec File is not present for 2021-12-18
# 2021-12-19
# Called Download data for date 2021-12-19
# Download of FNO for 2021-12-19 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo19DEC2021bhav.csv.zip
#  FNO File is not present for 2021-12-19
# Download of SEC for 2021-12-19 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_19122021.csv
# Download of SEC for 2021-12-19 Completed
#  Security File loading for date 2021-12-19 started
#  Security File loading for date 2021-12-19 Ended
# 2021-12-20
# Called Download data for date 2021-12-20
# Download of FNO for 2021-12-20 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo20DEC2021bhav.csv.zip
# Download of FNO for 2021-12-20 Completed
# Download of SEC for 2021-12-20 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_20122021.csv
# Download of SEC for 2021-12-20 Completed
#  Security File loading for date 2021-12-20 started
#  Security File loading for date 2021-12-20 Ended
#  Security File loading for date 2021-12-20 started
#  Security File loading for date 2021-12-20 Ended
# 2021-12-21
# Called Download data for date 2021-12-21
# Download of FNO for 2021-12-21 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo21DEC2021bhav.csv.zip
# Download of FNO for 2021-12-21 Completed
# Download of SEC for 2021-12-21 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_21122021.csv
# Download of SEC for 2021-12-21 Completed
#  Security File loading for date 2021-12-21 started
#  Security File loading for date 2021-12-21 Ended
#  Security File loading for date 2021-12-21 started
#  Security File loading for date 2021-12-21 Ended
# 2021-12-22
# Called Download data for date 2021-12-22
# Download of FNO for 2021-12-22 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo22DEC2021bhav.csv.zip
# Download of FNO for 2021-12-22 Completed
# Download of SEC for 2021-12-22 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_22122021.csv
# Download of SEC for 2021-12-22 Completed
#  Security File loading for date 2021-12-22 started
#  Security File loading for date 2021-12-22 Ended
#  Security File loading for date 2021-12-22 started
#  Security File loading for date 2021-12-22 Ended
# 2021-12-23
# Called Download data for date 2021-12-23
# Download of FNO for 2021-12-23 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo23DEC2021bhav.csv.zip
# Download of FNO for 2021-12-23 Completed
# Download of SEC for 2021-12-23 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_23122021.csv
# Download of SEC for 2021-12-23 Completed
#  Security File loading for date 2021-12-23 started
#  Security File loading for date 2021-12-23 Ended
#  Security File loading for date 2021-12-23 started
#  Security File loading for date 2021-12-23 Ended
# 2021-12-24
# Called Download data for date 2021-12-24
# Download of FNO for 2021-12-24 Started from https://archives.nseindia.com/content/historical/DERIVATIVES/2021/DEC/fo24DEC2021bhav.csv.zip
#  FNO File is not present for 2021-12-24
# Download of SEC for 2021-12-24 Started from https://archives.nseindia.com/products/content/sec_bhavdata_full_24122021.csv
#  Sec File is not present for 2021-12-24
