# %%
import pandas as pd
from zipfile import ZipFile
import numpy as np
from datetime import datetime, timedelta,date
from urllib.request import urlopen
from io import BytesIO

# %%
sec_base_url='https://archives.nseindia.com/products/content'
fno_base_url='https://archives.nseindia.com/content/historical/DERIVATIVES'

# %%
startdate=date(2021,11,18)
sec_date=startdate.strftime('%d%m%Y')
fno_day=startdate.strftime("%d")
fno_month=startdate.strftime("%b").upper()
fno_year=startdate.strftime("%Y")
fno_date=startdate.strftime('%d%b%Y').upper()

# %%
print(startdate,sec_date,fno_month,fno_year,fno_date)
# Out:
# 2021-11-18 18112021 NOV 2021 18NOV2021

# %%
sec_url=f"{sec_base_url}/sec_bhavdata_full_{sec_date}.csv"
fno_url=f"{fno_base_url}/{fno_year}/{fno_month}/fo{fno_date}bhav.csv.zip"
fno_csv_file_name=f"fo{fno_date}bhav.csv"

# %%
#https://archives.nseindia.com/products/content/sec_bhavdata_full_01102019.csv
#https://archives.nseindia.com/content/historical/DERIVATIVES/2019/OCT/fo01OCT2019bhav.csv.zip

# %%
#this is how to download csv zip then unzip it and then load to pandas

resp = urlopen(fno_url)
zipfile = ZipFile(BytesIO(resp.read()))
myfile=zipfile.extractall()
df=pd.read_csv(fno_csv_file_name)
df
# Out:
#       INSTRUMENT     SYMBOL    EXPIRY_DT  STRIKE_PR OPTION_TYP      OPEN  \
# 0         FUTIDX  BANKNIFTY  25-Nov-2021        0.0         XX  38102.35
# 1         FUTIDX  BANKNIFTY  30-Dec-2021        0.0         XX  38294.15
# 2         FUTIDX  BANKNIFTY  27-Jan-2022        0.0         XX  38450.00
# 3         FUTIDX   FINNIFTY  23-Nov-2021        0.0         XX  18700.00
# 4         FUTIDX   FINNIFTY  30-Nov-2021        0.0         XX  18730.05
# ...          ...        ...          ...        ...        ...       ...
# 68300     OPTSTK       ZEEL  27-Jan-2022      365.0         PE      0.00
# 68301     OPTSTK       ZEEL  27-Jan-2022      370.0         PE      0.00
# 68302     OPTSTK       ZEEL  27-Jan-2022      375.0         PE      0.00
# 68303     OPTSTK       ZEEL  27-Jan-2022      380.0         PE      0.00
# 68304     OPTSTK       ZEEL  27-Jan-2022      385.0         PE      0.00
#
#            HIGH       LOW     CLOSE  SETTLE_PR  CONTRACTS  VAL_INLAKH  \
# ...

# %%
date.strftime("%b").upper()
# Out:
# 'NOV'

# %%
start='2019-10-01'
end='2021-11-18'
daterange=np.arange(np.datetime64(start), np.datetime64(end)).astype(datetime)
print(daterange[0].strftime('%d%m%Y'))
day=daterange[0].strftime("%d")
month=daterange[0].strftime("%m")
year=daterange[0].strftime("%Y")
mmm=daterange[0].strftime("%b").upper()

print(day,month,year,mmm)

#date_list = [(start_date + datetime.timedelta(days = day)).isoformat() for day in range(number_of_days)]
# Out:
# 01102019
# 01 10 2019 OCT
