# %%
import pandas as pd
import numpy as np

# import urllib library
from urllib.request import urlopen
  
# import json
import json
import datetime
from pymongo import MongoClient

# %%
mongo_client=MongoClient()
db=mongo_client['OPTIONCHAIN']

# %%
# timeurl='https://opstra.definedge.com/api/optionsimulator/timestamps/2019-01-01&2021-01-01'
# # store the response of URL
# response = urlopen(timeurl)
  
# # storing the JSON response 
# # from url in data
# data_json = json.loads(response.read())

# %%
# date='09MAY2019'
# str(datetime.datetime.strptime(date, "%d%b%Y").date()-datetime.timedelta(days=60))

# %%
# time=datetime.datetime.fromtimestamp(int("1546336800")).strftime('%Y-%m-%d %H:%M:%S')
# print(time)

# %%
# dateyear=datetime.datetime.fromtimestamp(int("1548907200")).strftime('%d%b%Y').upper()
# print(dateyear)

# %%
# expdate='31JAN2019'
# endtime=' 15:30:00'
# endtime=expdate+endtime
# date_format = datetime.datetime.strptime(endtime,
#                                          "%d%b%Y %H:%M:%S")
# unix_time = datetime.datetime.timestamp(date_format)
# print(int(unix_time))

# %%
# date_format = datetime.datetime.strptime("2019-01-31 09:30:00",
#                                          "%Y-%m-%d %H:%M:%S")
# unix_time = datetime.datetime.timestamp(date_format)
# print(int(unix_time))

# %%
###########################################Chnage Expiries Here to selecct#######################################
#Set all expiries
#expiries=["31JAN2019"]
#expiries of 2019 excluding jan 2019
#expiries=["26DEC2019","19DEC2019","12DEC2019","05DEC2019","28NOV2019","21NOV2019","14NOV2019","07NOV2019","31OCT2019","24OCT2019","17OCT2019","10OCT2019","03OCT2019","26SEP2019","19SEP2019","12SEP2019","05SEP2019","29AUG2019","22AUG2019","14AUG2019","08AUG2019","01AUG2019","25JUL2019","18JUL2019","11JUL2019","04JUL2019","27JUN2019","20JUN2019","13JUN2019","06JUN2019","30MAY2019","23MAY2019","16MAY2019","09MAY2019"]#"02MAY2019","25APR2019","18APR2019","11APR2019","04APR2019","28MAR2019","20MAR2019","14MAR2019","07MAR2019","28FEB2019","21FEB2019","14FEB2019"]
#expiries of 2020
#expiries=["24DEC2020","17DEC2020","10DEC2020","03DEC2020","26NOV2020","19NOV2020","12NOV2020","05NOV2020","29OCT2020","22OCT2020","15OCT2020","08OCT2020","01OCT2020","24SEP2020","17SEP2020","10SEP2020","03SEP2020","27AUG2020","20AUG2020","13AUG2020","06AUG2020","30JUL2020","23JUL2020","16JUL2020","09JUL2020","02JUL2020","25JUN2020","18JUN2020","11JUN2020","04JUN2020","28MAY2020","21MAY2020","14MAY2020","07MAY2020","30APR2020","23APR2020","16APR2020","09APR2020","01APR2020","26MAR2020","19MAR2020","12MAR2020","05MAR2020","27FEB2020","20FEB2020","13FEB2020","06FEB2020","30JAN2020","23JAN2020","16JAN2020","09JAN2020","02JAN2020"]
#expiries of 2021
expiries=["30DEC2021","23DEC2021","16DEC2021","09DEC2021","02DEC2021","25NOV2021","18NOV2021","11NOV2021","03NOV2021","28OCT2021","21OCT2021","14OCT2021","30SEP2021","23SEP2021","16SEP2021","09SEP2021","02SEP2021","26AUG2021","18AUG2021","12AUG2021","05AUG2021","29JUL2021","22JUL2021","15JUL2021","08JUL2021","01JUL2021","24JUN2021","17JUN2021","10JUN2021","03JUN2021","27MAY2021","20MAY2021","12MAY2021","06MAY2021","29APR2021","22APR2021","15APR2021","08APR2021","01APR2021","25MAR2021","18MAR2021","10MAR2021","04MAR2021","25FEB2021","18FEB2021","11FEB2021","04FEB2021","28JAN2021","21JAN2021","14JAN2021","07JAN2021"]
expiries.reverse()

# %%
def get_dates(startdate,enddate):
    #Getting all timestapms
    startdate=startdate
    enddate=enddate
    try:
        timestampurl = f'https://opstra.definedge.com/api/optionsimulator/timestamps/{startdate}&{enddate}'

        # store the response of URL
        response = urlopen(timestampurl)

        # storing the JSON response 
        # from url in data
        data_json = json.loads(response.read())
        timestapms=list(data_json['timestamps'])
        return timestapms
    except Exception as e:
                print(f"Oops!, {e}, occurred wile geting time series from {timestampurl}")

# %%
# # To genrte unix 5 min timestamp range
# #genrating timestamps for year 2019,Set  start date as 15-20 days before actual start date you want.
# timestapms=get_dates('2019-04-01','2019-12-31')

# %%
# print(timestapms)

# %%
def mainfunc():
    for expiry in range(len(expiries)):
        #print(expiries[expiry])-->31JAN2019
        #Calculate last timestamp of expiry
        expdate=expiries[expiry]
        endtime=' 15:30:00'
        endtime=expdate+endtime
        date_format = datetime.datetime.strptime(endtime,
                                                 "%d%b%Y %H:%M:%S")
        end_unix_time = int(datetime.datetime.timestamp(date_format))
        ######Chnage Month End Expiry List###########################
        #monthendexpiries=["24DEC2020","26NOV2020","29OCT2020","24SEP2020","27AUG2020","30JUL2020","25JUN2020","28MAY2020","30APR2020","26MAR2020","27FEB2020","30JAN2020"]
        monthendexpiries=["30DEC2021","25NOV2021","28OCT2021","30SEP2021","26AUG2021","29JUL2021","24JUN2021","27MAY2021","29APR2021","25MAR2021","25FEB2021","28JAN2021"]
        monthendexpiries.reverse()
        if expiries[expiry] in monthendexpiries:
            startdate=str(datetime.datetime.strptime(expiries[expiry], "%d%b%Y").date()-datetime.timedelta(days=60))
        else:
            startdate=str(datetime.datetime.strptime(expiries[expiry], "%d%b%Y").date()-datetime.timedelta(days=20))
        
        ########################Change End Date Here ##############################
        timestapms=get_dates(startdate,'2021-12-31')
        
        
        # print(unix_time)#-->1548928800
        for i in range(len(timestapms)):
            if timestapms[i]==int(end_unix_time):
                break
            try:
                url = f'https://opstra.definedge.com/api/optionsimulator/optionchain/{timestapms[i]}&NIFTY&{expdate}'
                # store the response of URL
                response = urlopen(url)

                # storing the JSON response 
                # from url in data
                data_json = json.loads(response.read())
                 #Coverting into datatable
                time=datetime.datetime.fromtimestamp(int(timestapms[i])).strftime('%Y-%m-%d %H:%M:%S')
                optionchain=data_json['optionchaindata']
                fut=data_json['futuresPrice']
                spot=data_json['spotPrice']
                iv=data_json['iv']

                df=pd.DataFrame(optionchain)
                if not df.empty:
                    df['datetime']=time
                    df['expiry_date']=expdate
                    df['fut_price']=fut
                    df['iv']=iv
                    df['spot']=spot

                    df.replace(to_replace="-",value=0,inplace=True)
                    df.drop('index_x',axis=1,inplace=True)
                    df.drop('index_y',axis=1,inplace=True)
                    df.drop('name',axis=1,inplace=True)
                    df.replace(to_replace=np.nan,value=0,inplace=True)

                    # inserting into db
                    data=df.to_dict(orient='records')
                    print(f'Inserting data for nifty {time} started for expiry {expiries[expiry]}')
                    ###########################Chnage DB Name Here###################################################
                    db['NIFTY2021'].insert_many(data)
                    print(f'Inserting data for nifty {time} Ended for expiry {expiries[expiry]}')
            except Exception as e:
                print(f"Oops!, {e}, occurred for {url}")

# %%
df=mainfunc()
# Out:
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552276200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552276500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552276800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552277100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552277400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552277700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552278000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552278300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552278600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552278900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552279200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552279500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552279800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552280100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552280400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552280700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552281000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552281300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552281600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552281900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552282200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552282500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552282800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552283100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552283400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552283700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552284000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552284300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552284600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552284900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552285200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552285500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552285800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552286100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552286400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552286700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552287000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552287300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552287600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552287900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552288200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552288500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552288800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552289100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552289400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552289700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552290000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552290300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552290600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552290900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552291200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552291500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552291800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552292100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552292400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552292700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552293000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552293300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552293600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552293900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552294200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552294500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552294800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552295100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552295400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552295700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552296000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552296300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552296600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552296900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552297200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552297500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552297800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552298100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552298400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552362600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552362900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552363200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552363500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552363800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552364100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552364400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552364700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552365000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552365300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552365600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552365900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552366200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552366500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552366800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552367100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552367400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552367700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552368000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552368300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552368600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552368900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552369200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552369500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552369800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552370100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552370400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552370700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552371000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552371300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552371600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552371900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552372200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552372500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552372800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552373100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552373400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552373700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552374000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552374300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552374600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552374900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552375200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552375500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552375800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552376100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552376400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552376700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552377000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552377300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552377600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552377900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552378200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552378500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552378800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552379100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552379400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552379700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552380000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552380300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552380600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552380900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552381200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552381500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552381800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552382100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552382400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552382700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552383000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552383300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552383600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552383900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552384200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552384500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552384800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552449000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552449300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552449600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552449900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552450200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552450500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552450800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552451100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552451400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552451700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552452000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552452300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552452600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552452900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552453200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552453500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552453800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552454100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552454400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552454700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552455000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552455300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552455600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552455900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552456200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552456500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552456800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552457100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552457400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552457700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552458000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552458300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552458600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552458900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552459200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552459500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552459800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552460100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552460400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552460700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552461000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552461300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552461600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552461900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552462200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552462500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552462800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552463100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552463400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552463700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552464000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552464300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552464600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552464900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552465200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552465500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552465800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552466100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552466400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552466700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552467000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552467300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552467600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552467900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552468200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552468500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552468800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552469100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552469400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552469700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552470000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552470300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552470600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552470900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552471200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552535400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552535700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552536000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552536300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552536600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552536900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552537200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552537500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552537800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552538100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552538400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552538700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552539000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552539300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552539600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552539900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552540200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552540500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552540800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552541100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552541400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552541700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552542000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552542300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552542600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552542900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552543200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552543500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552543800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552544100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552544400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552544700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552545000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552545300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552545600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552545900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552546200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552546500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552546800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552547100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552547400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552547700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552548000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552548300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552548600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552548900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552549200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552549500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552549800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552550100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552550400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552550700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552551000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552551300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552551600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552551900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552552200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552552500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552552800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552553100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552553400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552553700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552554000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552554300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552554600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552554900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552555200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552555500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552555800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552556100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552556400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552556700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552557000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552557300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552557600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552621800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552622100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552622400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552622700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552623000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552623300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552623600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552623900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552624200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552624500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552624800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552625100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552625400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552625700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552626000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552626300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552626600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552626900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552627200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552627500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552627800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552628100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552628400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552628700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552629000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552629300&NIFTY&09MAY2019
# ...
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552883700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552884000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552884300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552884600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552884900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552885200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552885500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552885800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552886100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552886400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552886700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552887000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552887300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552887600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552887900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552888200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552888500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552888800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552889100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552889400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552889700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552890000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552890300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552890600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552890900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552891200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552891500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552891800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552892100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552892400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552892700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552893000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552893300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552893600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552893900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552894200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552894500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552894800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552895100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552895400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552895700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552896000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552896300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552896600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552896900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552897200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552897500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552897800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552898100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552898400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552898700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552899000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552899300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552899600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552899900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552900200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552900500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552900800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552901100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552901400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552901700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552902000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552902300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552902600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552902900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552903200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552967400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552967700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552968000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552968300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552968600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552968900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552969200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552969500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552969800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552970100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552970400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552970700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552971000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552971300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552971600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552971900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552972200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552972500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552972800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552973100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552973400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552973700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552974000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552974300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552974600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552974900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552975200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552975500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552975800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552976100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552976400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552976700&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552977000&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552977300&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552977600&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552977900&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552978200&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552978500&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552978800&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552979100&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552979400&NIFTY&09MAY2019
# Oops!, HTTP Error 500: INTERNAL SERVER ERROR, occurred for https://opstra.definedge.com/api/optionsimulator/optionchain/1552979700&NIFTY&09MAY2019

# %%
# #Calculate last timestamp of expiry
# expdate=expiries[0]
# endtime=' 15:30:00'
# endtime=expdate+endtime
# date_format = datetime.datetime.strptime(endtime,
#                                          "%d%b%Y %H:%M:%S")
# unix_time = datetime.datetime.timestamp(date_format)
# print(int(unix_time))

# %%
# while i in range(len(timestapms)):
#     print(timestapms[i])
#     # if timestapms[i]==int(unix_time):
#     #     break

# %%
# for i in range(len(timestapms)):
#     if timestapms[i]==int(unix_time):
#         break
#     otime=timestapms[i]
#     url = f'https://opstra.definedge.com/api/optionsimulator/optionchain/{timestapms[i]}&NIFTY&{expiries[0]}'

# %%
# print(otime)

# %%
# #Getting option Chain Data 
# # parameter for urlopen
# try:
#     url = 'https://opstra.definedge.com/api/optionsimulator/optionchain/1543407200&NIFTY&31JAN2019'

#     # store the response of URL
#     response = urlopen(url)

#     # storing the JSON response 
#     # from url in data
#     data_json = json.loads(response.read())

#     # print the json response
#     print(data_json)
# except Exception as e:
#     print(f"Oops!, {e}, occurred for {url}")
