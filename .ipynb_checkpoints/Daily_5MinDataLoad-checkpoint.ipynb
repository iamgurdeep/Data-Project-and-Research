# %% [markdown]
# # This File to load daily data (5 min) into MongoDB

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from pymongo import MongoClient
import datetime

# %%
def downloader_5(stock):
    data=getdata(stock,'Market5')
    start=data.tail(1).index[0]
    exchange=['.NS','.BO']
    try:
       # df_ns=yf.download(stock+exchange[0]).reset_index()
        ns=yf.download(stock+exchange[0],start=start,interval='5m')
        df_ns = ns.iloc[1: , :].copy()
        del ns    
    except:
        print(f'{stock+exchange[0]} not found')
            
    try:
        bo=yf.download(stock+exchange[1],start=start,interval='5m')
        df_bo = bo.iloc[1: , :].copy()
        del bo
        #df_bo=yf.download(stock+exchange[1]).reset_index()
    except:
        print(f'{stock+exchange[1]} not found')
    if not df_ns.empty:
        if not  df_bo.empty:
#             df_bo['Date']=pd.to_datetime(df_bo['Date'])
#             df_bo=df_bo.set_index('Date')
#             df_ns['Date']=pd.to_datetime(df_ns['Date'])
#             df_ns=df_ns.set_index('Date')
            if df_bo.shape[0]>1 & df_ns.shape[0]>1:
                df_ns.dropna(axis=0,how='any',inplace=True)
                df_bo.dropna(axis=0,how='any',inplace=True)
                df_ns['Volume']=df_ns['Volume'].astype(int)
                df_bo['Volume']=df_bo['Volume'].astype(int)
                df=pd.merge(df_ns,df_bo,on='Datetime',how='left')
                df=df.fillna(0)
                df['Volume']=df['Volume_x']+df['Volume_y']
                df=df[['Open_x','High_x','Low_x','Adj Close_x','Volume']]
                df=df.reset_index()
                df=df.rename(columns={'Open_x':'Open','High_x':'High','Low_x':'Low','Adj Close_x':'Close'})
                
                if df.iloc[-1: , -1:].values[0,0]==0:
                    df.drop(df.tail(1).index,inplace=True)
                return df
            elif df_ns.shape[0]>1:
                df_ns.dropna(axis=0,how='any',inplace=True)
                df_ns['Volume']=df_ns['Volume'].astype(int)
                df_ns=df_ns[['Open','High','Low','Adj Close','Volume']]
                df_ns=df_ns.reset_index()
                df_ns=df_ns.rename(columns={'Adj Close':'Close'})
                
                if df_ns.iloc[-1: , -1:].values[0,0]==0:
                    df_ns.drop(df_ns.tail(1).index,inplace=True)
                return df_ns
            
            else:
                df=pd.DataFrame()
                return df
            
        elif df_ns.shape[0]>1 :
            df_ns.dropna(axis=0,how='any',inplace=True)
            df_ns['Volume']=df_ns['Volume'].astype(int)
            df_ns=df_ns[['Open','High','Low','Adj Close','Volume']]
            df_ns=df_ns.reset_index()
            df_ns=df_ns.rename(columns={'Adj Close':'Close'})
            if df_ns.iloc[-1: , -1:].values[0,0]==0:
                df_ns.drop(df_ns.tail(1).index,inplace=True)
            return df_ns
    else:
        df=pd.DataFrame()
        return df

# %%
#This method read data from Mongo DB
def getdata(stock,db):
    stock=str(stock)
    mongo_client=MongoClient()
    db=mongo_client[db]
    data=db[stock].find()
    df=pd.DataFrame(list(data))
    df.drop("_id",axis=1,inplace=True)
    ###Covert to UTC to get the correct Values
    df['Datetime']=pd.to_datetime(df['Datetime']).dt.tz_localize('UTC').dt.tz_convert('Asia/Kolkata')
    #df['Datetime']=pd.to_datetime(df['Datetime'])
    df=df.set_index('Datetime')
    return df

# %%
# This Method load data into DB.
def to_db_5(stocklist):
    m_client=MongoClient()
    db=m_client["Market5"]
    print(f'5 min data Loading Starting')
    for stock in stocklist:
        print(f'{stock} 5 min data loading')
        stockdf=downloader_5(stock)
        try:
            if not stockdf.empty:
                data=stockdf.to_dict(orient='records')
                db[stock].insert_many(data)
                print (f'Data Load completed for stock {stock}')
            else:
                print(f'{stock} Nothing to load')
            
        except:
            print (f'Data Load failed for stock {stock}')
            pass
    print(f'5 min data Loading Ended')
    m_client.close()

# %%
#KSCL
#testdf=downloader_5('KSCL')

# %%
# To Fetch Stocks from DB
def get_stocklist(tbl):
    mongo_client=MongoClient()
    db=mongo_client["NIFTY500"]
    data=db[tbl].find()
    df=pd.DataFrame(list(data))
    df.drop("_id",axis=1,inplace=True)
    return df

# %%
df=get_stocklist('NIFTY500')
stocks=df.Symbol.to_list()

# %%
# Get the index of stock
#print(stocks.index('KSCL'))

# %%
#create new list of stocks starting from index you choose.
#stocks=stocks[277:]

# %%
#stocks

# %%
#provide list od stocks you want to downlad and load into mongo db
#stocks=['AAVAS']
#Calling load to db method 

to_db_5(stocks)
# Out:
# 5 min data Loading Starting
# 3MINDIA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock 3MINDIA
# ABB 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ABB
# POWERINDIA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock POWERINDIA
# ACC 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ACC
# AIAENG 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AIAENG
# APLAPOLLO 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock APLAPOLLO
# AUBANK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AUBANK
# AARTIDRUGS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AARTIDRUGS
# AARTIIND 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AARTIIND
# AAVAS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AAVAS
# ABBOTINDIA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ABBOTINDIA
# ADANIENT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ADANIENT
# ADANIGREEN 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ADANIGREEN
# ADANIPORTS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ADANIPORTS
# ATGL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ATGL
# ADANITRANS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ADANITRANS
# ABCAPITAL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ABCAPITAL
# ABFRL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ABFRL
# ADVENZYMES 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ADVENZYMES
# AEGISCHEM 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AEGISCHEM.BO: No data found, symbol may be delisted
# Data Load completed for stock AEGISCHEM
# AFFLE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AFFLE
# AJANTPHARM 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AJANTPHARM
# ALEMBICLTD 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ALEMBICLTD
# APLLTD 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock APLLTD
# ALKEM 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ALKEM
# ALKYLAMINE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ALKYLAMINE
# ALOKINDS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALOKINDS.BO: No data found, symbol may be delisted
# Data Load completed for stock ALOKINDS
# AMARAJABAT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AMARAJABAT
# AMBER 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AMBER
# AMBUJACEM 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AMBUJACEM
# ANGELONE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ANGELONE
# ANURAS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ANURAS
# APOLLOHOSP 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock APOLLOHOSP
# APOLLOTYRE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock APOLLOTYRE
# ASAHIINDIA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ASAHIINDIA
# ASHOKLEY 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ASHOKLEY
# ASHOKA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ASHOKA
# ASIANPAINT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ASIANPAINT
# ASTERDM 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ASTERDM
# ASTRAZEN 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ASTRAZEN
# ASTRAL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ASTRAL
# ATUL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ATUL
# AUROPHARMA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AUROPHARMA
# AVANTIFEED 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AVANTIFEED.BO: No data found, symbol may be delisted
# Data Load completed for stock AVANTIFEED
# DMART 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DMART
# AXISBANK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock AXISBANK
# BASF 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BASF
# BEML 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BEML
# BSE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BSE.BO: No data found, symbol may be delisted
# Data Load completed for stock BSE
# BAJAJ-AUTO 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BAJAJ-AUTO
# BAJAJCON 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BAJAJCON
# BAJAJELEC 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BAJAJELEC
# BAJFINANCE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BAJFINANCE
# BAJAJFINSV 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BAJAJFINSV
# BAJAJHLDNG 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BAJAJHLDNG
# BALAMINES 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BALAMINES
# BALKRISIND 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BALKRISIND
# BALRAMCHIN 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BALRAMCHIN
# BANDHANBNK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BANDHANBNK
# BANKBARODA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BANKBARODA
# BANKINDIA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BANKINDIA
# MAHABANK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock MAHABANK
# BATAINDIA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BATAINDIA
# BAYERCROP 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BAYERCROP
# BERGEPAINT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BERGEPAINT
# BDL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BDL
# BEL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BEL
# BHARATFORG 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BHARATFORG
# BHEL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BHEL
# BPCL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BPCL
# BHARATRAS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BHARATRAS
# BHARTIARTL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BHARTIARTL
# BIOCON 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BIOCON
# BIRLACORPN 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BIRLACORPN
# BSOFT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BSOFT
# BLUEDART 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BLUEDART
# BLUESTARCO 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BLUESTARCO
# BBTC 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BBTC
# BOSCHLTD 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BOSCHLTD
# BRIGADE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BRIGADE
# BRITANNIA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BRITANNIA
# BURGERKING 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock BURGERKING
# CCL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CCL
# CESC 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CESC
# CGPOWER 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CGPOWER
# CRISIL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CRISIL
# CSBBANK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CSBBANK
# CADILAHC 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CADILAHC
# CANFINHOME 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CANFINHOME
# CANBK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CANBK
# CAPLIPOINT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CAPLIPOINT.BO: No data found, symbol may be delisted
# Data Load completed for stock CAPLIPOINT
# CGCL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CGCL
# CARBORUNIV 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CARBORUNIV
# CASTROLIND 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CASTROLIND
# CEATLTD 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CEATLTD
# CENTRALBK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CENTRALBK
# CDSL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CDSL.BO: No data found, symbol may be delisted
# Data Load completed for stock CDSL
# CENTURYPLY 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CENTURYPLY
# CENTURYTEX 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CENTURYTEX
# CERA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CERA
# CHALET 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CHALET.BO: None
# Data Load completed for stock CHALET
# CHAMBLFERT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CHAMBLFERT
# CHOLAHLDNG 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CHOLAHLDNG.BO: None
# Data Load completed for stock CHOLAHLDNG
# CHOLAFIN 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CHOLAFIN
# CIPLA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CIPLA
# CUB 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CUB
# COALINDIA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock COALINDIA
# COCHINSHIP 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock COCHINSHIP
# COFORGE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - COFORGE.BO: None
# Data Load completed for stock COFORGE
# COLPAL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock COLPAL
# CAMS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CAMS.BO: None
# Data Load completed for stock CAMS
# CONCOR 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CONCOR
# COROMANDEL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock COROMANDEL
# CREDITACC 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CREDITACC.BO: None
# Data Load completed for stock CREDITACC
# CROMPTON 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CROMPTON
# CUMMINSIND 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CUMMINSIND
# CYIENT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock CYIENT
# DCBBANK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DCBBANK
# DCMSHRIRAM 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DCMSHRIRAM
# DLF 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DLF
# DABUR 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DABUR
# DALBHARAT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DALBHARAT.BO: None
# Data Load completed for stock DALBHARAT
# DEEPAKNTR 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DEEPAKNTR.BO: No data found, symbol may be delisted
# Data Load completed for stock DEEPAKNTR
# DELTACORP 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DELTACORP
# DHANI 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DHANI.BO: None
# Data Load completed for stock DHANI
# DHANUKA 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DHANUKA
# DBL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DBL
# DIVISLAB 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DIVISLAB
# DIXON 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DIXON
# LALPATHLAB 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock LALPATHLAB
# DRREDDY 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock DRREDDY
# EIDPARRY 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EIDPARRY
# EIHOTEL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EIHOTEL
# EPL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EPL
# EDELWEISS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EDELWEISS
# EICHERMOT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EICHERMOT
# ELGIEQUIP 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ELGIEQUIP
# EMAMILTD 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EMAMILTD
# ENDURANCE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ENDURANCE
# ENGINERSIN 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ENGINERSIN
# EQUITAS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EQUITAS
# EQUITASBNK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EQUITASBNK
# ERIS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ERIS
# ESCORTS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock ESCORTS
# EXIDEIND 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock EXIDEIND
# FDC 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock FDC
# FEDERALBNK 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock FEDERALBNK
# FACT 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock FACT
# FINEORG 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock FINEORG
# FINCABLES 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock FINCABLES
# FINPIPE 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - FINPIPE.BO: No data found, symbol may be delisted
# Data Load completed for stock FINPIPE
# FSL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock FSL
# FORTIS 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock FORTIS
# FRETAIL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock FRETAIL
# GAIL 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data Load completed for stock GAIL
# GMMPFAUDLR 5 min data loading
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GMMPFAUDLR.BO: No data found, symbol may be delisted
# Data Load completed for stock GMMPFAUDLR
# GALAXYSURF 5 min data loading
# GALAXYSURF.NS not found
# [*********************100%***********************]  1 of 1 completed
# GALAXYSURF.BO not found
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30160/16650580.py in <module>
#       3 #Calling load to db method
#       4
# ----> 5 to_db_5(stocks)
#       6
#
# ~\AppData\Local\Temp/ipykernel_30160/2844834040.py in to_db_5(stocklist)
#       6     for stock in stocklist:
#       7         print(f'{stock} 5 min data loading')
# ----> 8         stockdf=downloader_5(stock)
#       9         try:
#      10             if not stockdf.empty:
#
# ~\AppData\Local\Temp/ipykernel_30160/2525880923.py in downloader_5(stock)
#      18     except:
#      19         print(f'{stock+exchange[1]} not found')
# ---> 20     if not df_ns.empty:
#      21         if not  df_bo.empty:
#      22 #             df_bo['Date']=pd.to_datetime(df_bo['Date'])
#
# UnboundLocalError: local variable 'df_ns' referenced before assignment
